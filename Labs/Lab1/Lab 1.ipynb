# %% [markdown]
# # Lab 1: Intro to Jupyter Notebook, NumPy and MatPlotLib
#
# 1. Download Lab1 from classroom (on Dwarf).
#   1. firefox -> save to /tmp
#   2. Open terminal `Ctrl+Alt+T`
#   3. `mv /tmp/Lab1.zip ~/[location]/Lab1.zip`
#   4. `cd ~/[location]`
#   5. `unzip Lab1.zip`
# 2. Submit a rubric on classroom
#   1. For projects you will need to submit the rubric when you complete the project.
#   2. For practice, on classroom, submit Lab 1 with the rubric.
#
# ## Part 0: Intro to Jupyter Notebook
#
# ### Running Jupyter Notebook on a Dwarf
#
#
# 2. Open terminal `Ctrl+Alt+T` (on Dwarf)
# 3. run `jupyter notebook`
# 4. Browser opens with "Files" tab selected.
# 5. Find Lab1 through the Jupyter Notebook navigating through the directory system.
#
# <img src="new_notebook.png" alt="new notebook" width="200" align="right"/>
#
# ### Jupyter Notebook Basics
#
# 1. Create your first notebook.
#   1. Navigate to the folder Lab1.
#   2. In the upper left corner, click "New" and from the dropdown "Python 3"
# 2. Click on Untitled and rename your notebook Lab0
# 3. In your first Cell type `##Hello World` and press Run (`Shift+Enter`).
# 3. Change your first cell type to markdown and press Run (`Shift+Enter`).
#   1. [Markdown quick reference](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# 5. Create a new cell and type `print("Hello World")` into it and press Run (`Shift+Enter`).
#
# <img src="bar.png" alt="heading"/>
#
# ## Part 1: Intro to NumPy
#
# ### Create a NumPy Array
#
# 1. Import 'test.csv' into a ndarray using [NumPy genfromtext](https://numpy.org/devdocs/reference/generated/numpy.genfromtxt.html), [More info](https://numpy.org/devdocs/user/basics.io.genfromtxt.html)
# 2. Print data

# %%
import numpy as np
array1 = np.genfromtxt("./data/lab1.csv", dtype='float', delimiter=',')
array1
# Out:
# array([[ 4.28517983e+00, -3.06161700e-15, -1.57079633e+01],
#        [ 4.16158172e+00, -1.56016723e+00, -1.53906307e+01],
#        [ 3.59973217e+00, -2.96453965e+00, -1.50732981e+01],
#        [ 1.99456845e+00, -4.07287976e+00, -1.47559655e+01],
#        [ 1.37444086e+00, -4.77451121e+00, -1.44386329e+01],
#        [ 3.95480550e-01, -4.99937064e+00, -1.41213003e+01],
#        [ 1.36597596e+00, -4.72500409e+00, -1.38039677e+01],
#        [ 8.58003619e-01, -3.97880920e+00, -1.34866351e+01],
#        [ 3.20752121e+00, -2.83529932e+00, -1.31693025e+01],
#        [ 3.78656065e+00, -1.40866278e+00, -1.28519699e+01],
#        [ 3.15400343e+00,  1.58639667e-01, -1.25346374e+01],
#        [ 3.55363895e+00,  1.71010072e+00, -1.22173048e+01],
#        [ 2.21616208e+00,  3.09079493e+00, -1.18999722e+01],
#        [ 6.35491623e-01,  4.16284927e+00, -1.15826396e+01],
#        [ 3.25210817e+00,  4.81921079e+00, -1.12653070e+01],
#        [ 7.06689492e-02,  4.99433670e+00, -1.09479744e+01],
# ...

# %% [markdown]
# ### Explore NumPy array
#
# - [NumPy ndarray](https://numpy.org/devdocs/reference/arrays.ndarray.html)
# - [Array indexing](https://numpy.org/devdocs/reference/arrays.indexing.html)
# - [Square root](https://docs.scipy.org/doc/numpy/reference/generated/numpy.sqrt.html)
#
# #### Using the above links and NumPy documentation to complete the following tasks:
#
# - Print the shape of array1.
# - Print just column 2 of array1.
# - Print just row 5 of array1.
# - Use a single ndarray method to print the min of each column of array1 at once
# - Use a single ndarray method to print the max of each row of array1 at once
# - Use a single ndarray method to print the mean of each column of array1 at once
# - Use a single ndarray method to print the sum of each row of array1 at once
# - In one line use a ndarray method and numpy command to print the square root of the max of each column of array1
# - What is the shape of array2?
# - In one line use a ndarray method to convert it to a two dimensional array.

# %%
#part 1 here

array2 = np.array([[[0], [2], [4]],[[1], [3], [5]]]) #array2 given

print("shape of array1")
print(array1.shape)
print("\n\ncolumn 2 of array1")
print(array1[:, 1])
print("\n\nrow 5 of array1")
print(array1[4, :])  
print("\n\nmin of each column")
print(np.amin(array1, axis=0)) 
print("\n\nmax of each row")
print(np.amax(array1, axis=1)) 
print("\n\nmean of each column")
print(np.mean(array1, axis=0)) 
print("\n\nsum of each row")
print(np.sum(array1, axis=1))  
print("\n\none line of square root of max of column")
print(np.sqrt(np.amax(array1, axis=0)))
print("\n\nshape of array2")
print(array2.shape)
print("\n\nconvert array to two dimensional array")
print(array2.reshape((2, 3)))
# Out:
# shape of array1
# (100, 3)
#
#
# column 2 of array1
# [-3.06161700e-15 -1.56016723e+00 -2.96453965e+00 -4.07287976e+00
#  -4.77451121e+00 -4.99937064e+00 -4.72500409e+00 -3.97880920e+00
#  -2.83529932e+00 -1.40866278e+00  1.58639667e-01  1.71010072e+00
#   3.09079493e+00  4.16284927e+00  4.81921079e+00  4.99433670e+00
#   4.67073930e+00  3.88073232e+00  2.70320409e+00  1.25573994e+00
#  -3.17119598e-01 -1.85831228e+00 -3.21393805e+00 -4.24862715e+00
#  -4.85905784e+00 -4.98427388e+00 -4.61177147e+00 -3.77874787e+00
#  -2.56838696e+00 -1.10155266e+00  4.75280217e-01  2.00465268e+00
#   3.33384500e+00  4.33012702e+00  4.89401223e+00  4.96919232e+00
#   4.54815998e+00  3.67295854e+00  2.43098368e+00  9.46256222e-01
#  -6.32962268e-01 -2.14897456e+00 -3.45039506e+00 -4.40726682e+00
#  -4.92403877e+00 -4.94910721e+00 -4.47996887e+00 -3.56347086e+00
#  -2.29113261e+00 -7.90006980e-01  7.90006980e-01  2.29113261e+00
#   3.56347086e+00  4.47996887e+00  4.94910721e+00  4.92403877e+00
# ...

# %% [markdown]
# ## Part 2: MatPlotLib Basics
#
# - [MatPlotLib](https://matplotlib.org/)
# - [matplotlib.pyplot introduction](https://matplotlib.org/tutorials/introductory/pyplot.html)
#
# #### Using the above links and MatPlotLib documentation to complete the following tasks:
#
# Visualize the dataset with Matplotlib. All charts should include a title, axis labels and a legend when applicable.
# 1. Import 'lab1.csv' into a ndarray using genfromtxt.
# 2. Set figure size to 12x8. [Figure reference](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.figure.html)
# 2. Create a cartesian line graph of column 1 (on the X axis) vs column 0 (Y axis) using a magenta dashed line.
#     1. Include a title and axis labels.
# 3. Create a cartesian scatterplot with 3 datasets, (1,0) as red stars, (2,1) as green dots and (2,0) as blue squares.
#     1. Include a title, and a legend.
# 4. Create 6 graphs in 2 columns and 3 rows using [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html).
#     1. Row 1 is two graphs of (1,0), the first as a scatterplot and the second as a line graph
#     2. Row 2 is two graphs of (2,1), the first as a scatterplot and the second as a line graph
#     3. Row 3 is two graphs of (2,0), the first as a scatterplot and the second as a line graph
#     4. Include a title and axis labels for each subplot.
#     5. To insure there is enough space between subplots use [subplots_adjust](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)
#     6. Which are better as scatter plots and which are better as line graphs?

# %%
#part 2 here
import matplotlib.pyplot as plt

col0 = array1[:, 0]
col1 = array1[:, 1]
col2 = array1[:, 2]

plot1 = plt.figure(figsize=(12, 8)).subplots()
plot1.set_title("Plot 1")
plot1.set_xlabel("x")
plot1.set_ylabel("y")
plot1.plot(col1, col0, 'm--')

plot2 = plt.figure(figsize=(12, 8)).subplots()
plot2.plot(col1, col0, 'r*', col2, col1, 'go', col2, col0, "bs")
plot2.set_title("Plot 2")
plot2.legend(['Red star', 'Green dot', 'Blue square'])

plots3 = plt.figure(figsize=(12,8)).subplots(nrows=3, ncols=2)
for i in range(plots3.shape[0]):
    for j in range(plots3.shape[1]):
        plots3[i, j].set_title("Subplot " + str(i*2+j+1))
        plots3[i, j].set_xlabel('x')
        plots3[i, j].set_ylabel('y')
plots3[0, 0].scatter(col1, col0)
plots3[0, 1].plot(col1, col0)
plots3[1, 0].scatter(col2, col1)
plots3[1, 1].plot(col2, col1)
plots3[2, 0].scatter(col2, col0)
plots3[2, 1].plot(col2, col0)

plt.subplots_adjust(hspace=0.5)
plt.show()

# for the pair (1, 0), scatter plot is better 
# for (2, 1), both are clear but line graph shows the trend better 
# for (2, 0), scatterplot is better because it looks like there is no general trend in data

# %% [markdown]
# ## Part 3: Other ways to represent data
#
# - [MatPlotLib](https://matplotlib.org/)
# - [MatPlotLib mplot3d](https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html)
# - [MatPlotLib mplot3d demo](https://matplotlib.org/examples/mplot3d/scatter3d_demo.html)
# - [MatPlotLib hist](https://matplotlib.org/gallery/statistics/hist.html)
#
# #### Using the above links and MatPlotLib documentation to complete the following tasks:
#
# Visualize the dataset with Matplotlib. All charts must include a title and axis labels.
#
# 1. A 3D Cartesian figure: col 2 (X), col 1 (Y), and col 0 (Z).
# 2. A figure with 6 subplots
#     1. First row histograms with 10 bins of col 0, col 1, and col 2.
#     1. Second row scatter or line graphs (whichever you think is more meaningful) of (0,2), (1,2), and (2,2).

# %%
##3d figure here
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs=col2, ys=col1, zs=col0)
plt.show()

# %%
##Histograms here
subplots = plt.figure().subplots(nrows=2, ncols=3)
subplots[0, 0].hist(col0, bins=10)
subplots[0, 1].hist(col1, bins=10)
subplots[0, 2].hist(col2, bins=10)
subplots[1, 0].scatter(col0, col2)
subplots[1, 1].plot(col1, col2)
subplots[1, 2].plot(col2, col2)
plt.show()
